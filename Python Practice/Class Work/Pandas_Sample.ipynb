# %%
import pandas as pd

# %%
df = pd.read_csv("companytest.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (30, 3)

# %%
df.head(7)
# Out:
#   Company   Age  Salary
# 0     'a'  20.0     NaN
# 1       c  30.0     NaN
# 2     'a'  35.0  2300.0
# 3       c  40.0  3000.0
# 4       a  23.0  4000.0
# 5       c   NaN  5000.0
# 6       a   NaN  6000.0

# %%
df.tail()
# Out:
#    Company   Age  Salary
# 25       c  23.0  8943.0
# 26       a  34.0  8345.0
# 27       b  45.0  9284.0
# 28       b  23.0     NaN
# 29       b  35.0  2034.0

# %%
df.columns
# Out:
# Index(['Company', 'Age', 'Salary'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
# Company    27 non-null object
# Age        26 non-null float64
# Salary     23 non-null float64
# dtypes: float64(2), object(1)
# memory usage: 800.0+ bytes

# %%
df.describe()
# Out:
#              Age       Salary
# count  26.000000    23.000000
# mean   31.230769  4923.086957
# std     9.240380  2607.600271
# min    18.000000  1089.000000
# 25%    23.000000  3000.000000
# 50%    33.000000  4824.000000
# 75%    36.500000  7042.000000
# max    50.000000  9284.000000

# %%
df.index
# Out:
# RangeIndex(start=0, stop=30, step=1)

# %%
df.columns = ["Organization","Age","Compensation"]

# %%
df = df.rename(columns = {"Age":"age"})

# %%
df.rename(columns = {"age":"Age"}, inplace = True)

# %%
df
# Out:
#    Organization   Age  Compensation
# 0           'a'  20.0           NaN
# 1             c  30.0           NaN
# 2           'a'  35.0        2300.0
# 3             c  40.0        3000.0
# 4             a  23.0        4000.0
# 5             c   NaN        5000.0
# 6             a   NaN        6000.0
# 7           'c'  23.0        7000.0
# 8             a  34.0        8000.0
# 9             b  45.0        9000.0
# 10            b  23.0           NaN
# 11            b  34.0        1089.0
# 12            b  45.0           NaN
# 13            b  18.0        1234.0
# 14          NaN  40.0        3000.0
# 15            a  23.0        3000.0
# 16            c  23.0        3030.0
# 17            a  34.0        5000.0
# 18          NaN  22.0           NaN
# 19            c  32.0           NaN
# 20            a  37.0        3045.0
# 21            c  50.0        3184.0
# 22            a  21.0        4824.0
# 23            c   NaN        5835.0
# 24          NaN   NaN        7084.0
# ...

# %%
df.isna().sum()
# Out:
# Organization    3
# Age             4
# Compensation    7
# dtype: int64

# %%
df.drop("Age", axis="columns")
# Out:
#    Organization  Compensation
# 0           'a'           NaN
# 1             c           NaN
# 2           'a'        2300.0
# 3             c        3000.0
# 4             a        4000.0
# 5             c        5000.0
# 6             a        6000.0
# 7           'c'        7000.0
# 8             a        8000.0
# 9             b        9000.0
# 10            b           NaN
# 11            b        1089.0
# 12            b           NaN
# 13            b        1234.0
# 14          NaN        3000.0
# 15            a        3000.0
# 16            c        3030.0
# 17            a        5000.0
# 18          NaN           NaN
# 19            c           NaN
# 20            a        3045.0
# 21            c        3184.0
# 22            a        4824.0
# 23            c        5835.0
# 24          NaN        7084.0
# 25            c        8943.0
# 26            a        8345.0
# 27            b        9284.0
# 28            b           NaN
# 29            b        2034.0

# %%
df.drop_duplicates()
# Out:
#    Organization   Age  Compensation
# 0           'a'  20.0           NaN
# 1             c  30.0           NaN
# 2           'a'  35.0        2300.0
# 3             c  40.0        3000.0
# 4             a  23.0        4000.0
# 5             c   NaN        5000.0
# 6             a   NaN        6000.0
# 7           'c'  23.0        7000.0
# 8             a  34.0        8000.0
# 9             b  45.0        9000.0
# 10            b  23.0           NaN
# 11            b  34.0        1089.0
# 12            b  45.0           NaN
# 13            b  18.0        1234.0
# 14          NaN  40.0        3000.0
# 15            a  23.0        3000.0
# 16            c  23.0        3030.0
# 17            a  34.0        5000.0
# 18          NaN  22.0           NaN
# 19            c  32.0           NaN
# 20            a  37.0        3045.0
# 21            c  50.0        3184.0
# 22            a  21.0        4824.0
# 23            c   NaN        5835.0
# 24          NaN   NaN        7084.0
# ...

# %%
df.drop([10,0],axis="index")
# Out:
#    Organization   Age  Compensation
# 1             c  30.0           NaN
# 2           'a'  35.0        2300.0
# 3             c  40.0        3000.0
# 4             a  23.0        4000.0
# 5             c   NaN        5000.0
# 6             a   NaN        6000.0
# 7           'c'  23.0        7000.0
# 8             a  34.0        8000.0
# 9             b  45.0        9000.0
# 11            b  34.0        1089.0
# 12            b  45.0           NaN
# 13            b  18.0        1234.0
# 14          NaN  40.0        3000.0
# 15            a  23.0        3000.0
# 16            c  23.0        3030.0
# 17            a  34.0        5000.0
# 18          NaN  22.0           NaN
# 19            c  32.0           NaN
# 20            a  37.0        3045.0
# 21            c  50.0        3184.0
# 22            a  21.0        4824.0
# 23            c   NaN        5835.0
# 24          NaN   NaN        7084.0
# 25            c  23.0        8943.0
# 26            a  34.0        8345.0
# ...

# %%
df.iloc[0,0]
# Out:
# "'a'"

# %%
df.loc[8,"Compensation"]
# Out:
# 8000.0

# %%
df.loc[8,"Compensation"] = 9000

# %%
df.loc[8,"Compensation"]
# Out:
# 9000.0

# %%
df.loc[8:,:"Age"]
# Out:
#    Organization   Age
# 8             a  34.0
# 9             b  45.0
# 10            b  23.0
# 11            b  34.0
# 12            b  45.0
# 13            b  18.0
# 14          NaN  40.0
# 15            a  23.0
# 16            c  23.0
# 17            a  34.0
# 18          NaN  22.0
# 19            c  32.0
# 20            a  37.0
# 21            c  50.0
# 22            a  21.0
# 23            c   NaN
# 24          NaN   NaN
# 25            c  23.0
# 26            a  34.0
# 27            b  45.0
# 28            b  23.0
# 29            b  35.0

# %%
df.Organization
# Out:
# 0     'a'
# 1       c
# 2     'a'
# 3       c
# 4       a
# 5       c
# 6       a
# 7     'c'
# 8       a
# 9       b
# 10      b
# 11      b
# 12      b
# 13      b
# 14    NaN
# 15      a
# 16      c
# 17      a
# 18    NaN
# 19      c
# 20      a
# 21      c
# 22      a
# 23      c
# 24    NaN
# 25      c
# 26      a
# 27      b
# 28      b
# 29      b
# Name: Organization, dtype: object

# %%
df["Organization"]
# Out:
# 0     'a'
# 1       c
# 2     'a'
# 3       c
# 4       a
# 5       c
# 6       a
# 7     'c'
# 8       a
# 9       b
# 10      b
# 11      b
# 12      b
# 13      b
# 14    NaN
# 15      a
# 16      c
# 17      a
# 18    NaN
# 19      c
# 20      a
# 21      c
# 22      a
# 23      c
# 24    NaN
# 25      c
# 26      a
# 27      b
# 28      b
# 29      b
# Name: Organization, dtype: object

# %%
df["Organization"].unique()
# Out:
# array(["'a'", 'c', 'a', "'c'", 'b', nan], dtype=object)

# %%
df["Organization"].replace({"'a'":"a","'c'":'c'},inplace = True)

# %%
df["Organization"].unique()
# Out:
# array(['a', 'c', 'b', nan], dtype=object)

# %%
df["Organization"].isna().sum()
# Out:
# 3

# %%
df.dropna(subset = ["Organization"])
# Out:
#    Organization   Age  Compensation
# 0             a  20.0           NaN
# 1             c  30.0           NaN
# 2             a  35.0        2300.0
# 3             c  40.0        3000.0
# 4             a  23.0        4000.0
# 5             c   NaN        5000.0
# 6             a   NaN        6000.0
# 7             c  23.0        7000.0
# 8             a  34.0        9000.0
# 9             b  45.0        9000.0
# 10            b  23.0           NaN
# 11            b  34.0        1089.0
# 12            b  45.0           NaN
# 13            b  18.0        1234.0
# 15            a  23.0        3000.0
# 16            c  23.0        3030.0
# 17            a  34.0        5000.0
# 19            c  32.0           NaN
# 20            a  37.0        3045.0
# 21            c  50.0        3184.0
# 22            a  21.0        4824.0
# 23            c   NaN        5835.0
# 25            c  23.0        8943.0
# 26            a  34.0        8345.0
# 27            b  45.0        9284.0
# ...

# %%
df["Organization"].mode()[0]
# Out:
# 'a'

# %%
df["Organization"].fillna(df["Organization"].mode()[0],inplace = True)

# %%
df["Organization"].isna().sum()
# Out:
# 0

# %%
df["Age"].isna().sum()
# Out:
# 4

# %%
df.loc[4,"Age"] = 24

# %%
# %matplotlib inline
df["Age"].plot("box")

# %%
df["Age"].fillna(df["Age"].mean(),inplace = True)

# %%
df.isna().sum()
# Out:
# Organization    0
# Age             0
# Compensation    7
# dtype: int64

# %%
df["Compensation"].plot("box")

# %%
df["Compensation"].fillna(df["Compensation"].mean(),inplace = True)

# %%
df.isna().sum()
# Out:
# Organization    0
# Age             0
# Compensation    0
# dtype: int64

# %%
df["Organization"].value_counts()
# Out:
# a    13
# c     9
# b     8
# Name: Organization, dtype: int64

# %%
df[df.duplicated()]
# Out:
#    Organization   Age  Compensation
# 28            b  23.0   4966.565217

# %%
df.drop_duplicates(inplace = True)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Organization, Age, Compensation]
# Index: []

# %%
df[df["Organization"]=='c']
# Out:
#    Organization        Age  Compensation
# 1             c  30.000000   4966.565217
# 3             c  40.000000   3000.000000
# 5             c  31.269231   5000.000000
# 7             c  23.000000   7000.000000
# 16            c  23.000000   3030.000000
# 19            c  32.000000   4966.565217
# 21            c  50.000000   3184.000000
# 23            c  31.269231   5835.000000
# 25            c  23.000000   8943.000000

# %%
df[(df["Organization"]=='c') & (df["Age"]>40)]
# Out:
#    Organization   Age  Compensation
# 21            c  50.0        3184.0

# %%
df.query('Organization == "a" & Compensation>5000')
# Out:
#    Organization        Age  Compensation
# 6             a  31.269231        6000.0
# 8             a  34.000000        9000.0
# 24            a  31.269231        7084.0
# 26            a  34.000000        8345.0

# %%
df.groupby("Organization")["Age"].mean()
# Out:
# Organization
# a    29.733728
# b    35.000000
# c    31.504274
# Name: Age, dtype: float64

# %%
df.groupby(["Organization","Age"])["Compensation"].agg({"mean","count","median"})
# Out:
#                                mean  count       median
# Organization Age
# a            20.000000  4966.565217      1  4966.565217
#              21.000000  4824.000000      1  4824.000000
#              22.000000  4966.565217      1  4966.565217
#              23.000000  3000.000000      1  3000.000000
#              24.000000  4000.000000      1  4000.000000
#              31.269231  6542.000000      2  6542.000000
#              34.000000  7448.333333      3  8345.000000
#              35.000000  2300.000000      1  2300.000000
#              37.000000  3045.000000      1  3045.000000
#              40.000000  3000.000000      1  3000.000000
# b            18.000000  1234.000000      1  1234.000000
#              23.000000  4966.565217      1  4966.565217
#              34.000000  1089.000000      1  1089.000000
#              35.000000  2034.000000      1  2034.000000
#              45.000000  7750.188406      3  9000.000000
# ...

# %%
df["Age"].plot(kind ="hist")

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x = df["Age"],y = df["Compensation"])
plt.show()

# %%
df["Organization"].value_counts()
# Out:
# a    13
# c     9
# b     7
# Name: Organization, dtype: int64

# %%
df["Organization"].value_counts().plot(kind = "pie")

# %%
df
# Out:
#    Organization        Age  Compensation
# 0             a  20.000000   4966.565217
# 1             c  30.000000   4966.565217
# 2             a  35.000000   2300.000000
# 3             c  40.000000   3000.000000
# 4             a  24.000000   4000.000000
# 5             c  31.269231   5000.000000
# 6             a  31.269231   6000.000000
# 7             c  23.000000   7000.000000
# 8             a  34.000000   9000.000000
# 9             b  45.000000   9000.000000
# 10            b  23.000000   4966.565217
# 11            b  34.000000   1089.000000
# 12            b  45.000000   4966.565217
# 13            b  18.000000   1234.000000
# 14            a  40.000000   3000.000000
# 15            a  23.000000   3000.000000
# 16            c  23.000000   3030.000000
# 17            a  34.000000   5000.000000
# 18            a  22.000000   4966.565217
# 19            c  32.000000   4966.565217
# 20            a  37.000000   3045.000000
# 21            c  50.000000   3184.000000
# ...

# %%
col = df.select_dtypes(exclude = np.number).columns

# %%
pd.get_dummies(df[col])
# Out:
#     Organization_a  Organization_b  Organization_c
# 0                1               0               0
# 1                0               0               1
# 2                1               0               0
# 3                0               0               1
# 4                1               0               0
# 5                0               0               1
# 6                1               0               0
# 7                0               0               1
# 8                1               0               0
# 9                0               1               0
# 10               0               1               0
# 11               0               1               0
# 12               0               1               0
# 13               0               1               0
# 14               1               0               0
# 15               1               0               0
# 16               0               0               1
# ...

# %%
#One hot Encoding
org_encode = pd.get_dummies(df["Organization"])

# %%
df_new = pd.concat([org_encode,df[["Age","Compensation"]]], axis = 1)

# %%
df
# Out:
#    Organization        Age  Compensation
# 0             a  20.000000   4966.565217
# 1             c  30.000000   4966.565217
# 2             a  35.000000   2300.000000
# 3             c  40.000000   3000.000000
# 4             a  24.000000   4000.000000
# 5             c  31.269231   5000.000000
# 6             a  31.269231   6000.000000
# 7             c  23.000000   7000.000000
# 8             a  34.000000   9000.000000
# 9             b  45.000000   9000.000000
# 10            b  23.000000   4966.565217
# 11            b  34.000000   1089.000000
# 12            b  45.000000   4966.565217
# 13            b  18.000000   1234.000000
# 14            a  40.000000   3000.000000
# 15            a  23.000000   3000.000000
# 16            c  23.000000   3030.000000
# 17            a  34.000000   5000.000000
# 18            a  22.000000   4966.565217
# 19            c  32.000000   4966.565217
# 20            a  37.000000   3045.000000
# 21            c  50.000000   3184.000000
# ...

# %%
df["Organization"].unique()
# Out:
# array(['a', 'c', 'b'], dtype=object)

# %%
# Label Encoding
#df["Organization"].replace({'a':0,'b':1,"c":2})


from sklearn.preprocessing import LabelEncoder

LabelEncoder().fit_transform(df["Organization"])
# Out:
# array([0, 2, 0, 2, 0, 2, 0, 2, 0, 1, 1, 1, 1, 1, 0, 0, 2, 0, 0, 2, 0, 2,
#        0, 2, 0, 2, 0, 1, 1])

# %%
X = df_new.drop(columns = "Compensation")

# %%
y = df["Compensation"]

# %%
from sklearn.linear_model import LinearRegression

# %%
linear = LinearRegression()

# %%
linear.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
linear.coef_
# Out:
# array([ 199.70432167, -392.49368504,  192.78936337,   38.88690463])

# %%
linear.intercept_
# Out:
# 3684.899227936771

# %%
linear.predict([[0,1,0,50]])
# Out:
# array([5236.75077443])

# %%
pd.get_dummies(df["Organization"])
# Out:
#     a  b  c
# 0   1  0  0
# 1   0  0  1
# 2   1  0  0
# 3   0  0  1
# 4   1  0  0
# 5   0  0  1
# 6   1  0  0
# 7   0  0  1
# 8   1  0  0
# 9   0  1  0
# 10  0  1  0
# 11  0  1  0
# 12  0  1  0
# 13  0  1  0
# 14  1  0  0
# 15  1  0  0
# 16  0  0  1
# 17  1  0  0
# 18  1  0  0
# 19  0  0  1
# 20  1  0  0
# 21  0  0  1
# 22  1  0  0
# 23  0  0  1
# 24  1  0  0
# 25  0  0  1
# 26  1  0  0
# 27  0  1  0
# 29  0  1  0

# %%
import numpy as np

# %%
col = df.select_dtypes(exclude=np.number).columns

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()
label.fit_transform(df[col])
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# array([0, 2, 0, 2, 0, 2, 0, 2, 0, 1, 1, 1, 1, 1, 0, 0, 2, 0, 0, 2, 0, 2,
#        0, 2, 0, 2, 0, 1, 1])
