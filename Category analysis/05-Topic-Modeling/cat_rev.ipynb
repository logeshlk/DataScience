# %%
import pandas as pd
import numpy as np
import re

# %% [markdown]
# # Load Data

# %%
Data = pd.read_csv('All Reviews1.csv', encoding = "ISO-8859-1" )

# %%
Data.head(5)
# Out:
#    Unnamed: 0                                             Review
# 0           0  Update: Now that the tech issues have been add...
# 1           1  Changing my rating since the problems are fixe...
# 2           2  App worked pretty much as expected. Could have...
# 3           3  Highly recommend when you travel with Air Cana...
# 4           4  The app went from very useful to absolutely us...

# %%
Data.shape
# Out:
# (1763, 2)

# %%
Data.duplicated().value_counts()
# Out:
# False    1763
# dtype: int64

# %%
#pip install nltk

# %%
import nltk
from nltk.corpus import stopwords
from bs4 import BeautifulSoup
import re
import tqdm
import unicodedata

# %% [markdown]
# # Train and Test Data Split

# %%
reviews = Data['Review'].values

# %%
#creating the classification model using the classification algo
from sklearn.model_selection import train_test_split
train_reviews, test_reviews = train_test_split(reviews, test_size=0.2, random_state=42)

# %%
print("Train Reviews shape :", train_reviews.shape)
print("Test Reviews shape :", test_reviews.shape)
# Out:
# Train Reviews shape : (1410,)
# Test Reviews shape : (353,)

# %% [markdown]
# # Text Wrangling and Normalization

# %%
#function defined to remove html tags from data

def strip_html_tags(text):
  soup = BeautifulSoup(text, "html.parser")
  [s.extract() for s in soup(['iframe', 'script'])]
  stripped_text = soup.get_text()
  stripped_text = re.sub(r'[\r|\n|\r\n]+', '\n', stripped_text)
  return stripped_text

# %%
#function defined to remove unicode data

def remove_accented_chars(text):
  text = unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('utf-8', 'ignore')
  return text

# %%
# lower case and remove special characters\whitespaces

def pre_process_corpus(docs):
  norm_docs = []
  for doc in tqdm.tqdm(docs):
    doc = strip_html_tags(doc)
    doc = doc.translate(doc.maketrans("\n\t\r", "   "))
    doc = doc.lower()
    doc = remove_accented_chars(doc)
    #doc = contractions.fix(doc)
    # lower case and remove special characters\whitespaces
    doc = re.sub(r'[^a-zA-Z0-9\s]', '', doc, re.I|re.A)
    doc = re.sub(' +', ' ', doc)
    doc = doc.strip()  
    norm_docs.append(doc)
  
  return norm_docs

# %%
norm_train_reviews = pre_process_corpus(train_reviews)
# Out:
# 100%|██████████| 1410/1410 [00:03<00:00, 413.51it/s]

# %%
#Count Vecotorizer 

from sklearn.feature_extraction.text import CountVectorizer

# %%
# build BOW features on train reviews
cv = CountVectorizer(min_df=2, max_df=0.95,stop_words='english', ngram_range=(2,2))
cv_train_features = cv.fit_transform(norm_train_reviews)

# %%
cv_train_features.shape
# Out:
# (1410, 2340)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# build TFIDF features on train reviews
tv = TfidfVectorizer(use_idf=True, min_df=2, max_df=0.95, ngram_range=(2,2),
                     sublinear_tf=True, stop_words='english')
tv_train_features = tv.fit_transform(norm_train_reviews)

# %%
tv_train_features.shape
# Out:
# (1410, 2340)

# %%
norm_test_reviews = pre_process_corpus(test_reviews)
# Out:
# 100%|██████████| 353/353 [00:00<00:00, 3404.30it/s]

# %%
cv_test_features = cv.fit_transform(norm_test_reviews)
tv_test_features = tv.fit_transform(norm_test_reviews)

print ('CV Test Features shape :', cv_test_features.shape)
print ('TF-IDF Test Features shape :', tv_test_features.shape)
# Out:
# CV Test Features shape : (353, 384)
# TF-IDF Test Features shape : (353, 384)

# %% [markdown]
# # LDA - Latent Drichhlet Allocation

# %%
from sklearn.decomposition import LatentDirichletAllocation

# %%
LDA_cv = LatentDirichletAllocation(n_components=6,random_state=30)

# %%
LDA_cv.fit(cv_train_features)
# Out:
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#                           evaluate_every=-1, learning_decay=0.7,
#                           learning_method='batch', learning_offset=10.0,
#                           max_doc_update_iter=100, max_iter=10,
#                           mean_change_tol=0.001, n_components=6, n_jobs=None,
#                           perp_tol=0.1, random_state=30, topic_word_prior=None,
#                           total_samples=1000000.0, verbose=0)

# %%
cv.get_feature_names()
# Out:
# ['20 min',
#  '24 hours',
#  '30 minutes',
#  'able checkin',
#  'absolutely ridiculous',
#  'ac app',
#  'ac website',
#  'account app',
#  'accurate flight',
#  'add flight',
#  'add google',
#  'aeroplan account',
#  'aeroplan number',
#  'air canada',
#  'airline app',
#  'airplane mode',
#  'altitude status',
#  'android app',
#  'anymore consider',
#  'app acknowledge',
#  'app air',
#  'app app',
#  'app available',
#  'app awful',
#  'app bad',
#  'app boarding',
#  'app book',
#  'app check',
#  'app come',
#  'app completely',
#  'app convenient',
#  'app crashed',
#  'app crashes',
#  'app current',
#  'app did',
#  'app does',
#  'app doesnt',
#  'app dont',
#  'app download',
#  'app far',
#  'app flight',
#  'app going',
#  'app great',
#  'app horrible',
#  'app ive',
#  'app just',
#  'app keeps',
#  'app kept',
#  'app login',
#  'app mess',
#  'app months',
#  'app multiple',
#  'app needs',
#  'app negligible',
#  'app opens',
#  'app previous',
#  'app really',
#  'app says',
#  'app sucks',
#  'app takes',
#  'app terrible',
#  'app time',
#  'app track',
#  'app trash',
#  'app typical',
#  'app unable',
#  'app updated',
#  'app used',
#  'app useless',
#  'app watch',
#  'app website',
#  'app wont',
#  'app work',
#  'app worked',
#  'app working',
#  'app works',
#  'arrived airport',
#  'automatically loaded',
#  'available flight',
#  'bad app',
#  'bad experience',
#  'bad update',
#  'badly designed',
#  'barely flight',
#  'beneficial user',
#  'best airline',
#  'better better',
#  'boarding pass',
#  'boarding passes',
#  'boarding plane',
#  'boarding time',
#  'book flight',
#  'book flights',
#  'booked flight',
#  'booked flights',
#  'booking automatically',
#  'booking references',
#  'canada app',
#  'cancel flight',
#  'change password',
#  'check airport',
#  'check app',
#  'check boarding',
#  'check doesnt',
#  'check flight',
#  'check website',
#  'checkin app',
#  'checkin assistance',
#  'checkin doesnt',
#  'checkin easy',
#  'checkin time',
#  'code boarding',
#  'complete checkin',
#  'completely useless',
#  'confirmation number',
#  'confirmation numbers',
#  'connected wifi',
#  'connecting flight',
#  'consider valuable',
#  'constant errors',
#  'constantly crashes',
#  'countdown flight',
#  'crappy app',
#  'crashes time',
#  'create account',
#  'credit card',
#  'customer service',
#  'decent app',
#  'defeats purpose',
#  'delta app',
#  'delta staff',
#  'departure time',
#  'designed app',
#  'device compatible',
#  'did fix',
#  'did work',
#  'difficult app',
#  'displayed main',
#  'does app',
#  'does work',
#  'doesnt allow',
#  'doesnt let',
#  'doesnt load',
#  'doesnt register',
#  'doesnt work',
#  'dont bother',
#  'dont fly',
#  'dont know',
#  'dont use',
#  'download app',
#  'downloaded app',
#  'dumb app',
#  'earlier flight',
#  'easy boarding',
#  'easy use',
#  'eboarding passes',
#  'enter confirmation',
#  'error adding',
#  'error app',
#  'error message',
#  'everytime try',
#  'far good',
#  'finding boarding',
#  'flaws worked',
#  'flight app',
#  'flight confirmation',
#  'flight delayed',
#  'flight info',
#  'flight information',
#  'flight pass',
#  'flight point',
#  'flight status',
#  'fly air',
#  'fly delta',
#  'fly westjet',
#  'frustrating use',
#  'functioning app',
#  'galaxy s10',
#  'garbage app',
#  'gate agent',
#  'gate app',
#  'gate change',
#  'gate relevant',
#  'getting crash',
#  'getting network',
#  'good app',
#  'good idea',
#  'google pay',
#  'great app',
#  'great works',
#  'half time',
#  'half way',
#  'happened app',
#  'having app',
#  'having issues',
#  'horrible app',
#  'horrible update',
#  'hour flight',
#  'hours ago',
#  'im going',
#  'im unable',
#  'im using',
#  'inbound flight',
#  'inflight entertainment',
#  'info anymore',
#  'info app',
#  'info doesnt',
#  'info isnt',
#  'information app',
#  'information flight',
#  'information gate',
#  'information wont',
#  'international airport',
#  'international flight',
#  'international flights',
#  'issue android',
#  'issues delta',
#  'ive uninstalled',
#  'ive used',
#  'just crashes',
#  'just doesnt',
#  'just fine',
#  'just mobile',
#  'keeps crashing',
#  'keeps telling',
#  'kept asking',
#  'kept getting',
#  'latest update',
#  'leaf lounge',
#  'let check',
#  'limited functionality',
#  'link aeroplan',
#  'load boarding',
#  'loaded booked',
#  'login information',
#  'login password',
#  'look delta',
#  'looks like',
#  'lots bugs',
#  'love delta',
#  'main screen',
#  'makes app',
#  'makes want',
#  'maple leaf',
#  'matter times',
#  'message saying',
#  'mobile boarding',
#  'month ago',
#  'months ago',
#  'multiple times',
#  'need app',
#  'need use',
#  'needs fixed',
#  'negligible quality',
#  'network available',
#  'network wifi',
#  'new account',
#  'new app',
#  'new update',
#  'new version',
#  'number app',
#  'ok easy',
#  'old app',
#  'old phone',
#  'old version',
#  'online app',
#  'open app',
#  'outbound flight',
#  'pass app',
#  'pass checkin',
#  'pass delta',
#  'pass gate',
#  'pass print',
#  'passes displayed',
#  'password email',
#  'phone usless',
#  'point taking',
#  'poorly designed',
#  'pretty useless',
#  'previous app',
#  'previous version',
#  'print boarding',
#  'printed boarding',
#  'prior redesign',
#  'pull boarding',
#  'purpose app',
#  'qr code',
#  'quality update',
#  'really bad',
#  'really need',
#  'redesign flaws',
#  'reinstalled app',
#  'relevant info',
#  'reset password',
#  'retrieve booking',
#  'return flight',
#  'rouge player',
#  'running background',
#  'samsung note',
#  'says flights',
#  'says network',
#  'screen countdown',
#  'screen shot',
#  'screenshot boarding',
#  'seat assignments',
#  'seat selection',
#  'shot boarding',
#  'slow respond',
#  'space phone',
#  'stops working',
#  'sure happened',
#  'taking space',
#  'terrible app',
#  'terrible old',
#  'thank god',
#  'thats point',
#  'ticket counter',
#  'time gate',
#  'time just',
#  'time open',
#  'time using',
#  'time zones',
#  'totally useless',
#  'travel app',
#  'travel plans',
#  'tried logging',
#  'try app',
#  'try later',
#  'try use',
#  'trying checkin',
#  'unable add',
#  'unable login',
#  'unable reservation',
#  'unable reset',
#  'uninstalled reinstalled',
#  'united app',
#  'uniteds app',
#  'upcoming flights',
#  'update app',
#  'update just',
#  'update used',
#  'updated app',
#  'updated today',
#  'upgrade list',
#  'use app',
#  'use booking',
#  'use checkin',
#  'used gate',
#  'used good',
#  'used work',
#  'useless prior',
#  'user community',
#  'user experience',
#  'user friendly',
#  'user interface',
#  'using app',
#  'usless app',
#  'version app',
#  'view boarding',
#  'want fly',
#  'waste time',
#  'watch movies',
#  'web site',
#  'website app',
#  'whats going',
#  'wifi network',
#  'wont allow',
#  'wont let',
#  'work just',
#  'work old',
#  'worked fine',
#  'worked great',
#  'worked ok',
#  'works frustrating',
#  'works great',
#  'works just',
#  'worse previous',
#  'worst airline',
#  'worst app',
#  'year old',
#  'years ago',
#  'youre airport',
#  'youve checked',
#  'zero stars']

# %%
for index,topic in enumerate(LDA_cv.components_):
    print(f'THE TOP 20 WORDS FOR TOPIC #{index}')
    print([cv.get_feature_names()[i] for i in topic.argsort()[-20:]])
    print('\n')
# Out:
# THE TOP 20 WORDS FOR TOPIC #0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-223-897e1a6b1351> in <module>
#       1 for index,topic in enumerate(LDA_cv.components_):
#       2     print(f'THE TOP 20 WORDS FOR TOPIC #{index}')
# ----> 3     print([cv.get_feature_names()[i] for i in topic.argsort()[-20:]])
#       4     print('\n')
#
# <ipython-input-223-897e1a6b1351> in <listcomp>(.0)
#       1 for index,topic in enumerate(LDA_cv.components_):
#       2     print(f'THE TOP 20 WORDS FOR TOPIC #{index}')
# ----> 3     print([cv.get_feature_names()[i] for i in topic.argsort()[-20:]])
#       4     print('\n')
#
# IndexError: list index out of range

# %%
LDA_tv = LatentDirichletAllocation(n_components=6,random_state=42)

# %%
LDA_tv.fit(tv_train_features)
# Out:
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#                           evaluate_every=-1, learning_decay=0.7,
#                           learning_method='batch', learning_offset=10.0,
#                           max_doc_update_iter=100, max_iter=10,
#                           mean_change_tol=0.001, n_components=6, n_jobs=None,
#                           perp_tol=0.1, random_state=42, topic_word_prior=None,
#                           total_samples=1000000.0, verbose=0)

# %%
for index,topic in enumerate(LDA_tv.components_):
    print(f'THE TOP 20 WORDS FOR TOPIC #{index}')
    print([tv.get_feature_names()[i] for i in topic.argsort()[-20:]])
    print('\n')
# Out:
# THE TOP 20 WORDS FOR TOPIC #0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-226-276204f9a4b5> in <module>
#       1 for index,topic in enumerate(LDA_tv.components_):
#       2     print(f'THE TOP 20 WORDS FOR TOPIC #{index}')
# ----> 3     print([tv.get_feature_names()[i] for i in topic.argsort()[-20:]])
#       4     print('\n')
#
# <ipython-input-226-276204f9a4b5> in <listcomp>(.0)
#       1 for index,topic in enumerate(LDA_tv.components_):
#       2     print(f'THE TOP 20 WORDS FOR TOPIC #{index}')
# ----> 3     print([tv.get_feature_names()[i] for i in topic.argsort()[-20:]])
#       4     print('\n')
#
# IndexError: list index out of range

# %%
norm_reviews = pre_process_corpus(reviews)
# Out:
# 100%|██████████| 1763/1763 [00:00<00:00, 2137.40it/s]

# %%
# build BOW features on train reviews
cov = CountVectorizer(min_df=1, max_df=0.5,stop_words='english', ngram_range=(3,3))
cov_features = cov.fit_transform(norm_reviews)

# %%
LDA_cov = LatentDirichletAllocation(n_components=6,random_state=30)

# %%
LDA_cov.fit(cov_features)
# Out:
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#                           evaluate_every=-1, learning_decay=0.7,
#                           learning_method='batch', learning_offset=10.0,
#                           max_doc_update_iter=100, max_iter=10,
#                           mean_change_tol=0.001, n_components=6, n_jobs=None,
#                           perp_tol=0.1, random_state=30, topic_word_prior=None,
#                           total_samples=1000000.0, verbose=0)

# %%
cov.get_feature_names()
# Out:
# ['10 90',
#  '10 accompany',
#  '10 characters',
#  '10 different',
#  '10 doesnt',
#  '10 fix',
#  '10 hour',
#  '10 load',
#  '10 minute',
#  '10 minutes',
#  '10 new',
#  '10 seconds',
#  '10 time',
#  '10 times',
#  '10 tries',
#  '10 uninstall',
#  '100 buck',
#  '100 million',
#  '100 useless',
#  '1000 percent',
#  '1000 rent',
#  '1000s flights',
#  '100k option',
#  '100k super',
#  '100k travelers',
#  '1022 search',
#  '109 met',
#  '10am boards',
#  '10k build',
#  '10kb mobile',
#  '10th password',
#  '10th update',
#  '11 hour',
#  '11 hours',
#  '11 people',
#  '11 taken',
#  '11 years',
#  '1100 roughly',
#  '1122 improve',
#  '1126am ft',
#  '113019 update',
#  '12 fees',
#  '12 hour',
#  '12 hours',
#  '12 time',
#  '12 wheelchairs',
#  '120 time',
#  '1200 agent',
#  '121619 update',
#  '1230pm easy',
#  '13 reviews',
#  '1309 departing',
#  '14 hours',
#  '14 time',
#  '15 hours',
#  '15 minutes',
#  '15 release',
#  '15 steps',
#  '15 times',
#  '150 people',
#  '150 vouchers',
#  '15th decided',
#  '16 digit',
#  '160 expensive',
#  '160 million',
#  '17 nov',
#  '17th finally',
#  '18 rented',
#  '18 wheelchairs',
#  '19 degrees',
#  '19 stars',
#  '1924 delta',
#  '1950s version',
#  '1991 bring',
#  '1d 14',
#  '1nothing trie',
#  '1pm event',
#  '1s inflight',
#  '1st class',
#  '1st flight',
#  '1yr old',
#  '20 degrees',
#  '20 min',
#  '20 mins',
#  '20 minutes',
#  '20 people',
#  '20 second',
#  '20 seconds',
#  '20 upgrade',
#  '20 years',
#  '200 amex',
#  '200 dollar',
#  '200 gift',
#  '200 passengers',
#  '2000 check',
#  '2009 flown',
#  '2013ish biggest',
#  '2018 app',
#  '2018 hackers',
#  '2018 working',
#  '2019 100',
#  '2019 absolutely',
#  '2019 app',
#  '2019 business',
#  '2019 check',
#  '2019 end',
#  '2019 making',
#  '2019 march',
#  '2019 need',
#  '2019 oct',
#  '2019 summer',
#  '2019 time',
#  '2019 unstable',
#  '2019 update',
#  '2019 version',
#  '2019 wish',
#  '2019 works',
#  '20191115 force',
#  '20191129 needs',
#  '2020 allocated',
#  '2020 need',
#  '2020 prone',
#  '20200111 new',
#  '218 downgraded',
#  '21st avail',
#  '21st century',
#  '23 months',
#  '23 time',
#  '23 times',
#  '2300 phone',
#  '24 hour',
#  '24 hours',
#  '24 hr',
#  '24 hrs',
#  '240 dollars',
#  '2448 hours',
#  '24ghz 50ghz',
#  '25 buggy',
#  '25 person',
#  '25292019 recently',
#  '25k 35k',
#  '26th sent',
#  '27 garbage',
#  '2722020 working',
#  '27th 2019',
#  '29 fix',
#  '2nd flight',
#  '2nd issues',
#  '2nd person',
#  '2nd upgrade',
#  '2weeks flights',
#  '2x got',
#  '2xl android',
#  '30 40',
#  '30 app',
#  '30 credits',
#  '30 luggage',
#  '30 min',
#  '30 minute',
#  '30 minutes',
#  '30 passengers',
#  '300 preflight',
#  '3000 5hour',
#  '30000 change',
#  '3045 seconds',
#  '30min departure',
#  '312 trying',
#  '313 sat',
#  '32 access',
#  '34 flights',
#  '34years ago',
#  '35 hours',
#  '35 lbs',
#  '35 star',
#  '35k 50k',
#  '3hour delay',
#  '3rd attempt',
#  '3rd january',
#  '3x app',
#  '3x battery',
#  '40 minute',
#  '40 minutes',
#  '400 boarded',
#  '400 pm',
#  '400lbs luggage',
#  '404 dont',
#  '404 pages',
#  '417 424',
#  '417 just',
#  '424 managed',
#  '45 days',
#  '45 minute',
#  '45 minutes',
#  '45k error',
#  '46 times',
#  '50 fee',
#  '50 min',
#  '50 mins',
#  '50 time',
#  '500 characters',
#  '501 20191115',
#  '50ghz wifi',
#  '50k 100k',
#  '50k elite',
#  '50k gold',
#  '50k indication',
#  '58 minutes',
#  '5g networks',
#  '5hour business',
#  '5x useful',
#  '60 dollars',
#  '60 seconds',
#  '600 credited',
#  '600 future',
#  '6000 week',
#  '61 megs',
#  '6196 910am',
#  '6mo data',
#  '70 stays',
#  '70 years',
#  '72hrs advance',
#  '747 engine',
#  '747 mourn',
#  '747 seat',
#  '75 change',
#  '75 percent',
#  '75 time',
#  '75k status',
#  '79 years',
#  '80 time',
#  '800 waste',
#  '80mb app',
#  '81 reported',
#  '840 pm',
#  '86 meg',
#  '8h flight',
#  '8h flights',
#  '8h hours',
#  '90 functionality',
#  '90 mins',
#  '90 minutes',
#  '90 tablet',
#  '910am rdu',
#  '919 website',
#  '95 year',
#  '9hr flight',
#  'a9 2018',
#  'aa aaaa',
#  'aa cheater',
#  'aa just',
#  'aa loves',
#  'aa worst',
#  'aaaa aaaa2',
#  'aaaa air',
#  'aaaa opening',
#  'aaaa2aaaa1aaaaaaaa2aaaaaaaaaaaaaaaa aaaaaaaa',
#  'aaaa3aaaa licenes',
#  'aaaaaaaa aaaa3aaaa',
#  'aaaaaaaaaaaaaaa bring',
#  'aaaaaaaaaaaaaaaa12aaaaaaaaoaaaa aaaaaaaaaaaaoaaaaaaaaaaaaaaaaaaaaaaaaaaaaa',
#  'aaaaaaaaaaaaoaaaaaaaaaaaaaaaaaaaaaaaaaaaaa world',
#  'abandon app',
#  'abandoned nonfunctional',
#  'ability book',
#  'ability check',
#  'ability download',
#  'ability eupgrades',
#  'ability just',
#  'ability log',
#  'ability lose',
#  'ability make',
#  'ability manage',
#  'ability save',
#  'ability scan',
#  'ability tie',
#  'ability view',
#  'abit better',
#  'able access',
#  'able add',
#  'able afford',
#  'able book',
#  'able booking',
#  'able buy',
#  'able change',
#  'able check',
#  'able checkin',
#  'able complaincompliment',
#  'able complete',
#  'able connect',
#  'able destination',
#  'able easily',
#  'able flight',
#  'able itinerary',
#  'able link',
#  'able listen',
#  'able loads',
#  'able log',
#  'able login',
#  'able manage',
#  'able notice',
#  'able problem',
#  'able provide',
#  'able pull',
#  'able read',
#  'able request',
#  'able reservation',
#  'able retrieve',
#  'able save',
#  'able setting',
#  'able sign',
#  'able straight',
#  'able surprise',
#  'able track',
#  'able trips',
#  'able update',
#  'able upgrade',
#  'able use',
#  'able useless',
#  'able wanted',
#  'able watch',
#  'aboriginal aids',
#  'absalutely horrible',
#  'absolute garbage',
#  'absolute ridiculous',
#  'absolute trash',
#  'absolute worst',
#  'absolutely awful',
#  'absolutely bad',
#  'absolutely disastrous',
#  'absolutely disgusted',
#  'absolutely frustrating',
#  'absolutely garbage',
#  'absolutely horrible',
#  'absolutely love',
#  'absolutely loved',
#  'absolutely necessary',
#  'absolutely place',
#  'absolutely ridiculous',
#  'absolutely rubbish',
#  'absolutely sense',
#  'absolutely terrible',
#  'absolutely useless',
#  'absolutely value',
#  'absolutely wonderful',
#  'absolutly rediculous',
#  'absolutly trash',
#  'absurd thing',
#  'abysmal check',
#  'ac 75k',
#  'ac ac',
#  'ac account',
#  'ac agents',
#  'ac app',
#  'ac best',
#  'ac better',
#  'ac cargo',
#  'ac change',
#  'ac changed',
#  'ac check',
#  'ac clients',
#  'ac completes',
#  'ac consult',
#  'ac customer',
#  'ac dealing',
#  'ac develop',
#  'ac did',
#  'ac doesnt',
#  'ac dont',
#  'ac embarrassed',
#  'ac encourage',
#  'ac express',
#  'ac facilities',
#  'ac fixed',
#  'ac flight',
#  'ac flights',
#  'ac hear',
#  'ac inform',
#  'ac just',
#  'ac life',
#  'ac look',
#  'ac managed',
#  'ac million',
#  'ac mobile',
#  'ac need',
#  'ac outdone',
#  'ac problem',
#  'ac pw',
#  'ac reading',
#  'ac removed',
#  'ac reservation',
#  'ac respondent',
#  'ac response',
#  'ac return',
#  'ac sent',
#  'ac service',
#  'ac slow',
#  'ac staff',
#  'ac statusnope',
#  'ac tax',
#  'ac tell',
#  'ac tickets',
#  'ac time',
#  'ac took',
#  'ac tried',
#  'ac trip',
#  'ac unreliable',
#  'ac usual',
#  'ac website',
#  'ac win',
#  'ac1810 dec2',
#  'accent passport',
#  'accept account',
#  'accept address',
#  'accept bad',
#  'accept booking',
#  'accept credit',
#  'accept current',
#  'accept flight',
#  'accept new',
#  'accept policy',
#  'acceptable 2019',
#  'acceptable app',
#  'accepted pathetic',
#  'accepting new',
#  'accepts im',
#  'accepts login',
#  'access airplan',
#  'access alaska',
#  'access altitude',
#  'access anymore',
#  'access app',
#  'access associated',
#  'access boarding',
#  'access booking',
#  'access checked',
#  'access contacts',
#  'access data',
#  'access deleting',
#  'access deltatodayetc',
#  'access design',
#  'access despite',
#  'access digital',
#  'access email',
#  'access far',
#  'access flights',
#  'access galaxy',
#  'access gps',
#  'access hard',
#  'access inflight',
#  'access info',
#  'access information',
#  'access lounge',
#  'access loyalty',
#  'access mobile',
#  'access need',
#  'access onboarding',
#  'access outbound',
#  'access passes',
#  'access problem',
#  'access screenshots',
#  'access seat',
#  'access successfully',
#  'access ticket',
#  'access trip',
#  'access trips',
#  'access upcoming',
#  'access using',
#  'access wifi',
#  'accessible checkin',
#  'accessible form',
#  'accessible half',
#  'accessible phone',
#  'accessible seconds',
#  'accessing boarding',
#  'accessing location',
#  'accidentally flip',
#  'accidentally hit',
#  'accoint using',
#  'accomadating time',
#  'accommodating compassionate',
#  'accommodating love',
#  'accompany boarded',
#  'accomplish ive',
#  'according crash',
#  'account 24',
#  'account access',
#  'account account',
#  'account aeroplan',
#  'account app',
#  'account boarding',
#  'account check',
#  'account claiming',
#  'account computer',
#  'account create',
#  'account created',
#  'account customer',
#  'account delete',
#  'account did',
#  'account different',
#  'account doesnt',
#  'account downloaded',
#  'account encountering',
#  'account enter',
#  'account essentially',
#  'account evolving',
#  'account existing',
#  'account features',
#  'account flight',
#  'account flights',
#  'account froze',
#  'account guess',
#  'account having',
#  'account horrible',
#  'account ht',
#  'account info',
#  'account information',
#  'account issue',
#  'account issues',
#  'account just',
#  'account known',
#  'account laptop',
#  'account letting',
#  'account like',
#  'account locked',
#  'account makes',
#  'account manually',
#  'account match',
#  'account merge',
#  'account need',
#  'account nice',
#  'account number',
#  'account online',
#  'account opened',
#  'account password',
#  'account random',
#  'account refuses',
#  'account repeatedly',
#  'account reservation',
#  'account reset',
#  'account says',
#  'account sent',
#  'account set',
#  'account setting',
#  'account signed',
#  'account started',
#  'account stopped',
#  'account time',
#  'account times',
#  'account tried',
#  'account try',
#  'account trying',
#  'account use',
#  'account wont',
#  'account yep',
#  'accountable hint',
#  'accounts claims',
#  'accounts count',
#  'accounts flights',
#  'accounts obvious',
#  'accounts oversold',
#  'accumulated wont',
#  'accurate app',
#  'accurate flight',
#  'accurate info',
#  'accurate timely',
#  'accurately ill',
#  'accusations ill',
#  'achieve seemingly',
#  'achieved app',
#  'achieved staff',
#  'achow come',
#  'acknowledge bookings',
#  'acknowledge bring',
#  'acknowledge online',
#  'acknowledged having',
#  'acknowledgement request',
#  'aclaimeda amex',
#  'acount im',
#  'acs arcane',
#  'acs new',
#  'acs planes',
#  'act delta',
#  'acted handful',
#  'acted right',
#  'action apologies',
#  'active background',
#  'active boarding',
#  'activity actually',
#  'actual gate',
#  'actual guest',
#  'actual person',
#  'actually allow',
#  'actually approved',
#  'actually building',
#  'actually calm',
#  'actually check',
#  'actually comical',
#  'actually does',
#  'actually fly',
#  'actually followed',
#  'actually landed',
#  'actually make',
#  'actually middle',
#  'actually names',
#  'actually need',
#  'actually old',
#  'actually pay',
#  'actually purchase',
#  'actually replied',
#  'actually tell',
#  'actually telling',
#  'actually traveling',
#  'actually trick',
#  'actually trips',
#  'actually use',
#  'actually useful',
#  'actually useless',
#  'actually work',
#  'actually worked',
#  'actually working',
#  'actually works',
#  'actually worse',
#  'ad plays',
#  'adapt controls',
#  'add ability',
#  'add altitude',
#  'add app',
#  'add application',
#  'add basic',
#  'add boarding',
#  'add booked',
#  'add booking',
#  'add bookings',
#  'add calendar',
#  'add control',
#  'add existing',
#  'add family',
#  'add feature',
#  'add features',
#  'add fight',
#  'add flight',
#  'add flights',
#  'add google',
#  'add home',
#  'add horror',
#  'add imposible',
#  'add info',
#  'add ini',
#  'add intuitive',
#  'add manually',
#  'add maple',
#  'add miles',
#  'add multiple',
#  'add nav',
#  'add online',
#  'add option',
#  'add reservation',
#  'add reservations',
#  'add star',
#  'add stars',
#  'add terrible',
#  'add travel',
#  'add trip',
#  'add trips',
#  'add tripsfix',
#  'add unreliable',
#  'add upcoming',
#  'add value',
#  'add works',
#  'added app',
#  'added automatically',
#  'added bags',
#  'added basically',
#  'added bonus',
#  'added clear',
#  'added credit',
#  'added doesnt',
#  'added flights',
#  'added impressed',
#  'added incredible',
#  'added integration',
#  'added middle',
#  'added online',
#  'added passport',
#  'added phone',
#  'added stars',
#  'added times',
#  'adding bag',
#  'adding boarding',
#  'adding booked',
#  'adding confirmation',
#  'adding conformation',
#  'adding drain',
#  'adding flight',
#  'adding reservations',
#  'adding simply',
#  'adding trip',
#  'adding value',
#  'addition check',
#  'addition flight',
#  'addition just',
#  'addition letter',
#  'additional hours',
#  'additional times',
#  'additionally frustrating',
#  'additions dont',
#  'address credit',
#  'address example',
#  'address fact',
#  'address lost',
#  'address matter',
#  'address problem',
#  'address send',
#  'address unsurprisingly',
#  'addressed changing',
#  'addresses easy',
#  'addressing want',
#  'addridden flight',
#  'adds leg',
#  'adds lot',
#  'adds stress',
#  'adequately described',
#  'adjacent lose',
#  'adjustable fixed',
#  'adjustments fit',
#  'ads app',
#  'ads finished',
#  'ads overheard',
#  'ads play',
#  'ads played',
#  'ads problem',
#  'ads real',
#  'ads test',
#  'advance doesnt',
#  'advance morning',
#  'advance printed',
#  'advance seat',
#  'advanced just',
#  'advantage consumers',
#  'adventure ends',
#  'adventure game',
#  'adventure years',
#  'adventurous gameplay',
#  'advertised air',
#  'advice cabin',
#  'advice screenshot',
#  'advise airport',
#  'advise did',
#  'advised bookings',
#  'advises bookings',
#  'advisory delta',
#  'advisory existed',
#  'advisory home',
#  'aeriplan number',
#  'aero plan',
#  'aeromexico boarding',
#  'aeromexico checked',
#  'aeroplan access',
#  'aeroplan account',
#  'aeroplan air',
#  'aeroplan aircanada',
#  'aeroplan app',
#  'aeroplan aqm',
#  'aeroplan basically',
#  'aeroplan card',
#  'aeroplan case',
#  'aeroplan checkin',
#  'aeroplan confusing',
#  'aeroplan credentials',
#  'aeroplan details',
#  'aeroplan disasterand',
#  'aeroplan fine',
#  'aeroplan flights',
#  'aeroplan fully',
#  'aeroplan hoping',
#  'aeroplan id',
#  'aeroplan identify',
#  'aeroplan info',
#  'aeroplan just',
#  'aeroplan linked',
#  'aeroplan linking',
#  'aeroplan login',
#  'aeroplan lots',
#  'aeroplan nmbr',
#  'aeroplan number',
#  'aeroplan numbwr',
#  'aeroplan old',
#  'aeroplan password',
#  'aeroplan points',
#  'aeroplan pretty',
#  'aeroplan pull',
#  'aeroplan pw',
#  'aeroplan reports',
#  'aeroplan separate',
#  'aeroplan setting',
#  'aeroplan site',
#  'aeroplan status',
#  'aeroplan synced',
#  'aeroplan unlock',
#  'aeroplan yes',
#  'aeroplanaltitude sign',
#  'aeroplane account',
#  'aeroplane app',
#  'aeroplane tab',
#  'aeroplanes number',
#  'aeroplans allowed',
#  'aerplan member',
#  'aesthetic app',
#  'aesthetically use',
#  'affected app',
#  'affected hack',
#  'affected probably',
#  'afford cost',
#  'afford kinds',
#  'afraid try',
#  'againi timesand',
#  'age 10',
#  'age discover',
#  'age family',
#  'age largely',
#  'age signed',
#  'agent american',
#  'agent attempts',
#  'agent cancel',
#  'agent checkin',
#  'agent entering',
#  'agent guys',
#  'agent just',
#  'agent keeps',
#  'agent kept',
#  'agent manually',
#  'agent phone',
#  'agent print',
#  'agent refuses',
#  'agent say',
#  'agent site',
#  'agent used',
#  'agent weather',
#  'agent website',
#  'agents located',
#  'agents lufstansa',
#  'agents refused',
#  'agents trying',
#  'agents willing',
#  'agents worst',
#  'ages performance',
#  'aggravating try',
#  'aggravating worst',
#  'ago app',
#  'ago bad',
#  'ago best',
#  'ago doesnt',
#  'ago gave',
#  'ago great',
#  'ago havent',
#  'ago instead',
#  'ago iterations',
#  'ago mix',
#  'ago new',
#  'ago printed',
#  'ago prior',
#  'ago rejected',
#  'ago renewed',
#  'ago shows',
#  'ago time',
#  'ago tried',
#  'ago trying',
#  'ago updated',
#  'ago wife',
#  'ago youre',
#  'agree ts',
#  'agsin ubisoft',
#  'ahead confirm',
#  'ahead flight',
#  'ahead time',
#  'ahh twice',
#  'aiand erased',
#  'aids network',
#  'aim achieve',
#  'air canada',
#  'air canadas',
#  'air canadayour',
#  'air carrier',
#  'air china',
#  'air crappa',
#  'air fails',
#  'air gate',
#  'air lately',
#  'air lines',
#  'air miles',
#  'air nervous',
#  'air new',
#  'air sorry',
#  'air ticket',
#  'air transat',
#  'air transats',
#  'air travel',
#  'air watch',
#  'aircanada hoping',
#  'aircanada just',
#  'aircanada stock',
#  'aircanada web',
#  'aircanada weeks',
#  'aircanadano updates',
#  'aircanda general',
#  'aircraft bookings',
#  'aircraft impeccable',
#  'aircraft preboarding',
#  'aircraft types',
#  'aircrafts 10',
#  'airline afford',
#  'airline air',
#  'airline anymore',
#  'airline app',
#  'airline application',
#  'airline apps',
#  'airline avoid',
#  'airline bad',
#  'airline business',
#  'airline canadiens',
#  'airline check',
#  'airline company',
#  'airline customer',
#  'airline delta',
#  'airline doesnt',
#  'airline doing',
#  'airline dumb',
#  'airline exist',
#  'airline existed',
#  'airline fly',
#  'airline got',
#  'airline hate',
#  'airline hotel',
#  'airline id',
#  'airline itinerary',
#  'airline klm',
#  'airline likely',
#  'airline look',
#  'airline major',
#  'airline manage',
#  'airline named',
#  'airline option',
#  'airline options',
#  'airline period',
#  'airline quite',
#  'airline removes',
#  'airline sad',
#  'airline seeing',
#  'airline sense',
#  'airline service',
#  'airline simple',
#  'airline started',
#  'airline stay',
#  'airline stupid',
#  'airline sucks',
#  'airline supercedes',
#  'airline tied',
#  'airline unstable',
#  'airline use',
#  'airline used',
#  'airline way',
#  'airline worst',
#  'airline youad',
#  'airlineas specifications',
#  'airlines america',
#  'airlines app',
#  'airlines better',
#  'airlines book',
#  'airlines bookings',
#  'airlines delivered',
#  'airlines delta',
#  'airlines elite',
#  'airlines expected',
#  'airlines good',
#  'airlines like',
#  'airlines making',
#  'airlines quickly',
#  'airlines sad',
#  'airlines simply',
#  'airlines single',
#  'airlines straightforward',
#  'airlines supported',
#  'airlines thank',
#  'airlines use',
#  'airlines westjet',
#  'airlines wind',
#  'airlines world',
#  'airlines years',
#  'airolane mode',
#  'airplan function',
#  'airplan mode',
#  'airplane mode',
#  'airplanesa320200b7878dreamlineri did',
#  'airport 10',
#  'airport additional',
#  'airport aeromexico',
#  'airport announcement',
#  'airport app',
#  'airport approached',
#  'airport arrival',
#  ...]

# %%
for index,topic in enumerate(LDA_cov.components_):
    print(f'THE TOP 20 WORDS FOR TOPIC #{index}')
    print([cov.get_feature_names()[i] for i in topic.argsort()[-20:]])
    print('\n')
# Out:
# THE TOP 20 WORDS FOR TOPIC #0
# ['app just', 'canada app', 'previous app', 'airline apps', 'open app', 'app wont', 'airplane mode', 'old app', 'customer service', 'app works', 'using app', 'airline app', 'flight info', 'new app', 'app doesnt', 'boarding passes', 'confirmation number', 'doesnt work', 'air canada', 'boarding pass']
#
#
# THE TOP 20 WORDS FOR TOPIC #1
# ['connected wifi', 'pretty good', 'app needs', 'download app', 'doesnt work', 'old app', 'app sucks', 'check app', 'use app', 'check flight', 'new update', 'app does', 'customer service', 'new app', 'easy use', 'flight status', 'does work', 'boarding pass', 'boarding passes', 'air canada']
#
#
# THE TOP 20 WORDS FOR TOPIC #2
# ['upcoming flights', 'app worked', 'ive used', 'aeroplan number', 'airline app', 'new version', 'half time', 'worst app', 'app does', 'completely useless', 'user friendly', 'new app', 'customer service', 'let check', 'wont let', 'old app', 'useless app', 'boarding passes', 'air canada', 'boarding pass']
#
#
# THE TOP 20 WORDS FOR TOPIC #3
# ['good app', 'flight status', 'fly delta', 'download app', 'worst app', 'use app', 'reset password', 'credit card', 'confirmation number', 'previous version', 'rouge player', 'old version', 'app works', 'new app', 'app doesnt', 'old app', 'boarding passes', 'doesnt work', 'boarding pass', 'air canada']
#
#
# THE TOP 20 WORDS FOR TOPIC #4
# ['flight information', 'app does', 'garbage app', 'multiple times', 'fly delta', 'change seats', 'app says', 'customer service', 'book flights', 'print boarding', 'app doesnt', 'app just', 'good app', 'credit card', 'reset password', 'use app', 'doesnt work', 'boarding passes', 'air canada', 'boarding pass']
#
#
# THE TOP 20 WORDS FOR TOPIC #5
# ['flight number', 'aeroplan account', 'departure time', 'seat selection', 'link aeroplan', 'error message', 'book flight', 'booking reference', 'booking flight', 'previous version', 'useless app', 'uninstall reinstall', 'keeps crashing', 'doesnt work', 'use app', 'app great', 'old app', 'aeroplan number', 'air canada', 'boarding pass']

# %%
cov_features
# Out:
# <1763x26187 sparse matrix of type '<class 'numpy.int64'>'
# 	with 28269 stored elements in Compressed Sparse Row format>

# %%
top_cov = LDA_cov.fit(cov_features)

# %%
for index,topic in enumerate(LDA_cov.components_):
    print(f'THE TOP 20 WORDS FOR TOPIC #{index}')
    print([cov.get_feature_names()[i] for i in topic.argsort()[-20:]])
    print('\n')
# Out:
# THE TOP 20 WORDS FOR TOPIC #0
# ['boarding passes phone', 'display boarding pass', 'happened app does', 'air canada app', 'boarding pass line', 'load boarding pass', 'app boarding pass', 'doesnt work wont', 'able check app', 'just like airline', 'app does provide', 'boarding pass frustrating', 'wont let add', 'says network available', 'app worked great', 'way eboarding passes', 'ive used app', 'retrieve boarding pass', 'print boarding pass', 'app doesnt work']
#
#
# THE TOP 20 WORDS FOR TOPIC #1
# ['app completely useless', 'save boarding passes', 'app having technical', 'use app time', 'load boarding pass', 'wont let log', 'app ive used', 'access boarding pass', 'times doesnt work', 'completely useless app', 'enter aeroplan number', 'doesnt let check', 'new air canada', 'boarding pass gate', 'retrieve boarding pass', 'boarding pass flights', 'worst app ive', 'just doesnt work', 'air canada app', 'turn airplane mode']
#
#
# THE TOP 20 WORDS FOR TOPIC #2
# ['fly delta app', 'air canada rouge', 'google pay support', 'load boarding pass', 'add boarding passes', 'app air canada', 'app worked great', 'just use website', 'lose boarding pass', 'upcoming trips app', 'app kept crashing', 'link aeroplan number', 'electronic boarding pass', 'boarding passes app', 'boarding pass doesnt', 'access boarding pass', 'check boarding pass', 'air canada app', 'air canada mobile', 'save boarding pass']
#
#
# THE TOP 20 WORDS FOR TOPIC #3
# ['boarding pass anymore', 'having look enter', 'salt lake city', 'entertainment page did', 'like air canada', 'boarding pass disappears', 'app boarding passes', 'app doesnt update', 'app used work', 'paper boarding pass', 'print boarding passes', 'time check app', 'flights boarding passes', 'unfortunately air canada', 'view boarding pass', 'air canada app', 'air canada account', 'flying air canada', 'enter confirmation number', 'wont let check']
#
#
# THE TOP 20 WORDS FOR TOPIC #4
# ['dont waste time', 'boarding time gate', 'error message try', 'air canada website', 'app does work', 'fly air canada', 'just doesnt work', 'flying air canada', 'checkin doesnt work', 'view boarding pass', 'screen shot boarding', 'unable reset password', 'view com world', 'just boarding pass', 'printed boarding pass', 'flight boarding pass', 'bring old app', 'app doesnt work', 'air canada rouge', 'boarding pass app']
#
#
# THE TOP 20 WORDS FOR TOPIC #5
# ['displayed online boarding', 'time flight confirmation', 'information shortcomings wants', 'booking getting flight', 'wants confirmation number', 'online boarding pass', 'number time flight', 'works booking getting', 'pass dig emails', 'flight information shortcomings', 'boarding pass dig', 'app works booking', 'shortcomings wants confirmation', 'number displayed online', 'garbage app doesnt', 'screenshot boarding pass', 'flight confirmation number', 'keeps giving error', 'confirmation number time', 'print boarding pass']

# %%
top_cov.shape
# Out:
# (1763, 6)

# %%
Data['LDA_topic_cv']=top_cov.argmax(axis=1)

# %%
Data
# Out:
#       Unnamed: 0                                             Review  \
# 0              0  Update: Now that the tech issues have been add...
# 1              1  Changing my rating since the problems are fixe...
# 2              2  App worked pretty much as expected. Could have...
# 3              3  Highly recommend when you travel with Air Cana...
# 4              4  The app went from very useful to absolutely us...
# ...          ...                                                ...
# 1758        3602  Terrible to find the flight,  information onli...
# 1759        3604  Worst App again.... Automatically shuts down. ...
# 1760        3609  My flight information just dissapears during l...
# 1761        3613  This app just randomly loses your data, and cr...
# 1762        3614        Boarding passes only show up half the time.
#
#       LDA_topic_cv
# 0                2
# 1                1
# 2                3
# 3                3
# 4                2
# ...            ...
# 1758             5
# 1759             4
# 1760             4
# 1761             4
# 1762             2
#
# [1763 rows x 3 columns]

# %% [markdown]
# # LSA Model

# %%
import os
import smart_open
import gensim

# %%
from gensim import models, corpora

# %%
from nltk import word_tokenize
from nltk.corpus import stopwords
 
NUM_TOPICS = 10
STOPWORDS = stopwords.words('english')
 
#def clean_text(text):
#    tokenized_text = word_tokenize(text.lower())
#    cleaned_text = [t for t in tokenized_text if t not in STOPWORDS and re.match('[a-zA-Z\-][a-zA-Z\-]{2,}', t)]
#    return cleaned_text
 
# For gensim we need to tokenize the data and filter out stopwords
tokenized_data = []
for text in norm_reviews:
    tokenized_data.append(cov_features)
 
 
# Build a Dictionary - association word to numeric id
dictionary = corpora.Dictionary(tokenized_data)
 
# Transform the collection of texts to a numerical form
corpus = [dictionary.doc2bow(text) for text in tokenized_data]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-255-cc4ad0e5c2cf> in <module>
#      17
#      18 # Build a Dictionary - association word to numeric id
# ---> 19 dictionary = corpora.Dictionary(tokenized_data)
#      20
#      21 # Transform the collection of texts to a numerical form
#
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\corpora\dictionary.py in __init__(self, documents, prune_at)
#      85
#      86         if documents is not None:
# ---> 87             self.add_documents(documents, prune_at=prune_at)
#      88
#      89     def __getitem__(self, tokenid):
#
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\corpora\dictionary.py in add_documents(self, documents, prune_at)
#     206
#     207             # update Dictionary with the document
# --> 208             self.doc2bow(document, allow_update=True)  # ignore the result, here we only care about updating token ids
#     209
#     210         logger.info(
#
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\corpora\dictionary.py in doc2bow(self, document, allow_update, return_missing)
#     251         counter = defaultdict(int)
#     252         for w in document:
# --> 253             counter[w if isinstance(w, unicode) else unicode(w, 'utf-8')] += 1
#     254
#     255         token2id = self.token2id
#
# TypeError: decoding to str: need a bytes-like object, csr_matrix found

# %%
# Build the LSI model
lsi_model = models.LsiModel(corpus=corpus, num_topics=NUM_TOPICS, id2word=dictionary)

# %%
for idx in range(NUM_TOPICS):
    # Print the first 10 most representative topics
    print("Topic #%s:" % idx, lsi_model.print_topic(idx, 10))
 
print("=" * 20)
# Out:
# Topic #0: 0.047*"this app is completely useless prior to the redesign it had some flaws but all around worked ok and easy to use booking were automatically loaded if you booked through flight pass checkin was easy all boarding passes were displayed and your main screen was a countdown to your next flight now there not even a point of taking space up on your phone with this usless app" + 0.047*"update now that the tech issues have been addressed changing to 4 stars from 1 star earlier the checkin functionality is great and also like to call out ability to view incoming flights often 34 flights down need to have altitude status and progression integrated into the app" + 0.047*"what a horrible update trading updated color schemes for greatly decreased functionality makes absolutely no sense the app is now just a collection of links to websites where you used to be able to change seats bid for upgrades get your boarding pass etc these functions now just redirect you to a web browser even after the redirect you need to enter your booking number and personal details before using the function how is this not automatic making westjet look better every day" + 0.047*"everytime we try to use it theres a problem never had a successful checkin always get an error luggage payment went through but it says 0 luggage on the app etc" + 0.047*"trips disappear every single trip ive used this app for the trip has disappeared from the app at some point usually more than once then i need to find my reservation number and search for it again to get my boarding pass this is very frustrating it would be great if this was fixed up otherwise the app is very good" + 0.047*"cant look up upcoming trips on this app it just returns errors and tells me to try again later" + 0.047*"what a garbage app doesnt update any information gate seat and it keeps giving me an error when adding the boarding pass such an embarrassment" + 0.047*"since the update it has been abysmal cannot check in through it the option just doesnt work if you can still request upgrade or get on standby i cant find it in the app the old version was infinitely better this has now just become an information display only no functionality" + 0.047*"i like the delta app it has more options and is better than lots of other airline apps the only thing they changed that i dont like is on the checkin it does not prompt you for bags i always check one and many people do not so i can see why now i have to reopen it to check bags up front i know i can do it on the kiosk but like to get done before i hit the airport" + 0.047*"found a perfect flight selected all my options went to pay input all my information and it told me i was missing some information nothing was left blank nothing was highlighted in red tried 7 times including starting over from scratch twice finally it gave me fatal error and lost my entire booking am not likely to use the app again"
# Topic #1:
# Topic #2:
# Topic #3:
# Topic #4:
# Topic #5:
# Topic #6:
# Topic #7:
# Topic #8:
# Topic #9:
# ====================

# %%
from sklearn.cluster import KMeans

NUM_CLUSTERS = 6
km = KMeans(n_clusters=NUM_CLUSTERS, max_iter=10000, n_init=100, random_state=42).fit(cov_features)
km
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=10000,
#        n_clusters=6, n_init=100, n_jobs=None, precompute_distances='auto',
#        random_state=42, tol=0.0001, verbose=0)

# %%
feature_names = cov.get_feature_names()
topn_features = 10
ordered_centroids = km.cluster_centers_.argsort()[:, ::-1]

# %%
for cluster_num in range(NUM_CLUSTERS):
    key_features = [feature_names[index] 
                        for index in ordered_centroids[cluster_num, :topn_features]]
    #modules = cat_cluster[cat_cluster['kmeans_cluster'] == cluster_num]['Module'].values.tolist()
    print('CLUSTER #'+str(cluster_num+1))
    print('Key Features:', key_features)
    #print('Impacted Module', modules)
    print('-'*80)
# Out:
# CLUSTER #1
# Key Features: ['way eboarding passes', 'like need connected', 'airport useless international', 'check airport useless', 'cell phone connected', 'didnt allow worked', 'passes security app', 'time cell phone', 'network wifi opened', 'flight arrived destination']
# --------------------------------------------------------------------------------
# CLUSTER #2
# Key Features: ['air canada app', 'print boarding pass', 'app doesnt work', 'air canada rouge', 'boarding pass app', 'turn airplane mode', 'access boarding pass', 'save boarding pass', 'app worked great', 'retrieve boarding pass']
# --------------------------------------------------------------------------------
# CLUSTER #3
# Key Features: ['carry bookings make', 'extremely delayed refreshing', 'based aeroplan number', 'make sure info', 'bookings make sure', 'new updated version', 'number youll manually', 'wont carry bookings', 'manually app extremely', 'sure info ahead']
# --------------------------------------------------------------------------------
# CLUSTER #4
# Key Features: ['bring boarding passes', 'boarding passes phone', 'having problems fact', 'printed boarding passes', 'remembered passwords past', 'probably security measure', 'completely electronic flight', 'simultaneously logged requiring', 'electronic flight printed', 'measure delta server']
# --------------------------------------------------------------------------------
# CLUSTER #5
# Key Features: ['surprised easy surprise', 'positive review app', 'purchase flight times', 'easy surprise short', 'flight wanted 919', 'app flight wanted', '3rd attempt book', 'flight 1100 roughly', 'review app start', '1100 roughly great']
# --------------------------------------------------------------------------------
# CLUSTER #6
# Key Features: ['gate updates departure', 'updates departure times', 'app used trip', 'maps airports automatic', 'cool app used', 'automatic tracking bags', 'airports automatic tracking', 'different times tediusannoying', 'flight haf reenter', 'losing flight haf']
# --------------------------------------------------------------------------------
